# %%
#Importing the required Libraries
import pandas as pd
import nltk
from nltk.stem import PorterStemmer
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS

# %%
#News for topic modeling
news=["""India’s coronavirus tally has crossed 56 lakh after the country reported a single-day spike of 83,347 cases on Wednesday. The country’s total Covid-19 death toll has also crossed the 90,000-mark after 1,085 deaths were reported in the last 24 hours.

On the brighter side, the number of active cases in India has fallen by almost 90,000 in the last 24 hours. India now has 9,68,377 active cases while the number of people who have recovered has increased to 45, 87,613.

Follow Coronavirus Live Updates

Over the past few days, the health ministry has been reiterating that India’s Covid-19 recoveries are the highest in the world despite the high number of daily cases.

India’s daily case average is the highest among all other nations in the world including the United States, which is the worst affected country in terms of cases and death toll.

Besides the improving recovery rate, India’s health ministry has also confirmed that the country has one of the lowest fatality rates in the world. However, the daily death toll has remained above 1,000 for over a month now.

The government also said that India’s daily Covid testing capacity has gone up to over 12 lakh and over 6.5 crore tests have been conducted so far. According to the Indian Council of Medical Research (ICMR), 6,62,79,462 samples have been tested up to September 22.

Maharashtra remains the worst affected state in India but it has been reporting a higher number of recoveries in comparison to daily infections. A total of 33,015 people have died in the state due to the novel coronavirus.
advertisement

Meanwhile, Delhi has been witnessing a sharp surge in cases over the past few weeks. The total number of active cases in the national capital has gone up to 30,941.""",


"""On the contrary, 14 states in India are witnessing lower positive rates, confirmed the health ministry. Some of these states are Mizoram, Manipur, Arunachal Pradesh, Gujarat, Sikkim, Tripura, J&K (UT), Odisha, Assam, Punjab and Uttarakhand.
hennai Super Kings head coach Stephen Fleming said it will take a bit more time to see MS Dhoni at his best in Indian Premier League (IPL) 2020, considering the long break he has had from competitive cricket. However, Fleming expressed delight at those big sixes from the CSK captain in the final over of their 16-run defeat to Rajasthan Royals on Tuesday.

MS Dhoni is facing the heat for his approach in Chennai Super Kings' failed chase of 217 in their 2nd IPL 2020 match in Sharjah. The CSK skipper failed to get going straight away after walking in at No. 7 even as Faf du Plessis was single-handed trying to keep the asking rate under control.

IPL 2020 Points Table

Dhoni needed 12 balls for his first 9 runs after he arrived in the middle in the 14th over of CSK's chase. He had sent in the likes of debutant Ruturaj Gaikwad and Kedar Jadhav ahead of him. CSK failed to keep the momentum going as Dhoni and du Plessis were happy taking singles before the latter got going.

"We have this question every year. He was in in the 12th (14th) over, which is pretty much optimal time, and sort of batted accordingly," Fleming said after CSK's defeat.

"He is coming back from not playing a huge amount of cricket, so the expectations, to see him at his best, is gonna take some time.

"But you see him towards the end, he was very good."

Notably, MS Dhoni had defended his decision to come in at No. 7, saying he did not find it ideal to walk in higher up the order due to the long break he had in the lead up to IPL 2020.
advertisement

"I haven't batted for a long time. 14-day quarantine doesn't help. Also wanted to try different things, give opportunities to Sam. Have the opportunity to try different things. If it doesn't work, you can always go back to your strengths," Dhoni said.
Will Faf du Plessis open for CSK?

Meanwhile, Fleming said it was not the batting which let Chennai Super Kings down on Tuesday against Rajasthan Royals, stressing that the 3-time champions are looking to use their resources smartly.

The CSK head coach also hinted Faf du Plessis might open the batting for them in the next few games. With Rayudu's injury concerns and Murali Vijay's form (or the lack of it), CSK are still looking to find their best combination at the top of the order.

"Faf du Plessis carried the form, so we weren't too far away. It wasn't the batting that was the worry to be honest," Fleming said.

But what if wars were won or lost over mere computer codes?

Cyber power is slowly becoming the new value addition to a country's strength. We have been witnessing increased cases of espionage, cyber warfare, bot attacks and strong surveillance systems to monitor people. Given that India's border tensions with China have soured in recent times, how much power does India hold in cyberspace?

According to a report titled 'National Cyber Power Index' published by the Belfer Center of Harvard Kennedy School, USA, when it comes to cyber power, India fares far behind.
India's ranking in cyberspace

Of the 30 countries analysed in the report, India ranked at number 21. The top five most powerful countries in cyberspace according to the report (in particular order) are the United States, China, the United Kingdom, Russia and the Netherlands.

The report stated, "These countries both signal in strategies and in previously attributed cyber-attacks that they intend to use cyber to achieve policy goals and have the capabilities to achieve them"

At 21st position, India is followed by Turkey, Iran, Brazil, Ukraine and Saudi Arabia. Egypt stood at last position. These countries come to have low intent and low capabilities.
advertisement

According to the report, "Countries that fall into this category either are not actively developing the capability and intent to project power in cyberspace, or have not published (or had published about them) a sufficient amount of information on their cyber strategy, cyber-attacks attributed to them, or capabilities used to measure cyber power in this study".
Why India ranks low

The National Cyber Power Index (NCPI) is a composite index of two broad factors - capacity and intentions. These two factors are based on seven sub-parameters - Defence, Offence, Surveillance, Control, Intelligence, Commercial and Norms. In none of the factors stated above does India fare anywhere in the top. The full report can be found here.

India ranked 24th in the Defence category, 29th in Control, 15th in intelligence, 12th in Norms, 26th in surveillance and 19th in commercial parameters. There were 13 such countries including India, which neither show intent nor build capabilities in the 'offence' or destructive intents and capabilities.

The rankings based broadly on intentions and capabilities show that India doesn't have high intent or capabilities to be a cyber powerful nation.

The DIU spoke to Simon Jones, one of the authors of the Belfer Center's NCPI report and expert on Technology and Security related matters and asked his opinion on India ranking low.

"It was striking to us that India, which has placed such an emphasis on growing its tech sector, does not have a National Cyber Strategy, only its 2013 National Cyber Policy. While it is welcome that India is due to publish a National Cyber Strategy soon, having and regularly updating a National Cyber Strategy allows India to set its national priorities, explain why they are important, and ensure it has the public and private sector resources and capabilities needed to deliver. India was also deemed to have relatively weak data privacy and cyber-crime laws, despite significant levels of cyber-crime experienced by Indians," Jones explained.

The report defined 'intent' as "a measurement of the quality and quantity of government planning initiatives (i.e. national cybersecurity strategies, crisis plans, and other related government planning documents). It is a subjective assessment of the government's "observed behaviour" on cyber relevant issues".

Cyber Capabilities according to the report were "measurements of the quality and quantity of country output related to one or more cyber objectives (i.e. the number of patents filed per year, number of global top security firms, number of skilled workers)".
China's cyber power neck and neck with US

At the same time, we must note that China, India's immediate neighbour ranks one in three indicators (Surveillance, Defence and Commercial) and features in the top 5 of all the seven indicators. This is also why it ranks number two in terms of being a cyber power.

China, like other top countries, has laid out its objectives and intentions clearly. This is the reason why it ranks at the top.

Jones reiterated how important this becomes for India to enhance its abilities.

"India should also pay attention to the priorities and objectives of neighbours, including China. In the NCPI, China is the highest-scoring country for intent for the 'Growing National Cyber and Technology Competence' objective, having demonstrated its willingness to use legal and illegal means to grow its domestic technology industry. India should focus on protecting commercially sensitive information against types of attacks that Chinese actors have been observed exploiting," said Jones.
advertisement

"China is also the second-highest scoring country for the 'Controlling and Manipulating the Information Environment' objective. India should enhance its ability to counter foreign propaganda. This could include calling out and attributing foreign propaganda and disinformation, or strengthening laws that force social media companies to take down disinformation", he added.

But according to Professor Burton Cleetus, a medicine historian at Delhi’s Jawaharlal Nehru University’s department of history, 2020 is actually the worst year from a psychological point of view.

Professor Cleetus said, “The year 2020 is the worst primarily, if we are measuring the discourse of the disease. With schools shut, businesses running down and restrictions on many activities, people tend to believe that their lives have come to a stagnant situation.”

Professor Syed Irfan Habib, historian of science and modern political history and former Maulana Azad Chair at the National Institute of Educational Planning and Administration in Delhi, believes it will be incorrect to call 2020 the worst year in Indian history.

Professor Habib said, “The year 2020 has been bad for sure, but we cannot call it the worst in history. Certainly, the virus has impacted people from all strata of society, though we are hoping that this will be over by the end of this year. If it continues to spread like this, then we might have to think afresh.”

So there we have it; the jury is out on the current year. Whether 2020 is the worst year ever will only be known retrospectively. Sometime in the future, there will be debates on whether 536 AD, 2020 or some other tumultuous year in the future is the worst.""", 

"""Narcotics Control Bureau will soon send summons to Deepika Padukone after her name cropped up during the drug probe in the Sushant Singh Rajput death case. The actress's WhatsApp chats with her manager, Karishma, were retrieved by the NCB in which the two were seen discussing drugs. Karishma works with Jaya Saha, with whom Rhea Chakraborty chatted about CBD oil, as a manager in Kwan talent management agency.

Karishma has been summoned by the NCB for questioning today along with Jaya Saha, who was grilled for four hours on Monday. According to NCB sources, the agency has also acquired chats between Jaya Saha and Karishma in which they are discussing drugs.

In the WhatsApp chats between Deepika and Karishma, which have been acquired by the NCB, the Chhapaak actress enquires about hash. Her text reads, "You have maal?" She further adds, "Hash na? Not weed." Karishma then tells her that she will provide her drugs through another person.

Apart from Deepika Padukone, Sara Ali Khan, Shraddha Kapoor and Rakul Preet Singh's name have also came up in the case. These actresses will also be summoned for questioning in the case.

Sara Ali Khan made her Bollywood debut with Sushant Singh Rajput in 2018 film Kedarnath. While Shraddha Kapoor was seen sharing screen space with Sushant in Nitesh Tiwari's film Chhichhore (2019).

Earlier, Jaya Saha's WhatsApp chats with Rhea Chakraborty were released by the Enforcement Directorate. The chats revealed that Jaya advised Rhea to use a few drops of a substance in Sushant Singh Rajput's tea or coffee. The message reads, "Use 4 drops in tea, let him sip it . Give it 30-40 mins to kick in." It was later found out that the duo was discussing CBD Oil.
advertisement

Rhea Chakraborty is currently at Byculla jail for allegedly procuring drugs for Sushant Singh Rajput. Her judicial custody is ending today. According to sources, the NCB might seek extension of her judicial custody at the sessions court. The agency is likely to seek extension of Showik's custody as well.

Sushant Singh Rajput was found hanging dead at his Mumbai home on June 14. The Central Bureau of Investigation (CBI) is investigating the case"""]

# %%
from nltk.stem import WordNetLemmatizer
stemmer=PorterStemmer()

#Function for stemming Lemmatized tokens
def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text,pos='v'))

#Function for Preprocessing the news
def preprocess(text):
    result=[]
    for token in simple_preprocess(text):
        if token not in STOPWORDS:
            result.append(lemmatize_stemming(token))
            
    return result

# %%
#Calling the fuction 
processed_toks=[]

for tok in news:
    processed_toks.append(preprocess(tok))

# %%
processed_toks
# Out:
# [['india',
#   'coronaviru',
#   'talli',
#   'cross',
#   'lakh',
#   'countri',
#   'report',
#   'singl',
#   'day',
#   'spike',
#   'case',
#   'wednesday',
#   'countri',
#   'total',
#   'covid',
#   'death',
#   'toll',
#   'cross',
#   'mark',
#   'death',
#   'report',
#   'hour',
#   'brighter',
#   'number',
#   'activ',
#   'case',
#   'india',
#   'fall',
#   'hour',
#   'india',
#   'activ',
#   'case',
#   'number',
#   'peopl',
#   'recov',
#   'increas',
#   'follow',
#   'coronaviru',
#   'live',
#   'updat',
#   'past',
#   'day',
#   'health',
#   'ministri',
#   'reiter',
#   'india',
#   'covid',
#   'recoveri',
#   'highest',
#   'world',
#   'despit',
#   'high',
#   'number',
#   'daili',
#   'case',
#   'india',
#   'daili',
#   'case',
#   'averag',
#   'highest',
#   'nation',
#   'world',
#   'includ',
#   'unit',
#   'state',
#   'worst',
#   'affect',
#   'countri',
#   'term',
#   'case',
#   'death',
#   'toll',
#   'improv',
#   'recoveri',
# ...

# %%
len(processed_toks)
# Out:
# 9

# %%
#BoW on Cleaned_toks
from gensim import corpora
dictionary=corpora.Dictionary(processed_toks)
print(dictionary)
# Out:
# Dictionary(1307 unique tokens: ['accord', 'activ', 'advertis', 'affect', 'averag']...)

# %%
bow_corpus=[dictionary.doc2bow(tok) for tok in processed_toks]
bow_corpus
# Out:
# [[(0, 1),
#   (1, 3),
#   (2, 1),
#   (3, 2),
#   (4, 1),
#   (5, 1),
#   (6, 1),
#   (7, 1),
#   (8, 8),
#   (9, 1),
#   (10, 1),
#   (11, 1),
#   (12, 3),
#   (13, 1),
#   (14, 4),
#   (15, 3),
#   (16, 1),
#   (17, 2),
#   (18, 5),
#   (19, 2),
#   (20, 4),
#   (21, 1),
#   (22, 1),
#   (23, 1),
#   (24, 1),
#   (25, 1),
#   (26, 1),
#   (27, 1),
#   (28, 2),
#   (29, 1),
#   (30, 2),
#   (31, 1),
#   (32, 1),
#   (33, 2),
#   (34, 2),
#   (35, 1),
#   (36, 1),
#   (37, 1),
#   (38, 1),
#   (39, 8),
#   (40, 1),
#   (41, 1),
#   (42, 2),
#   (43, 1),
#   (44, 1),
#   (45, 1),
#   (46, 1),
#   (47, 1),
#   (48, 2),
#   (49, 1),
#   (50, 2),
#   (51, 1),
#   (52, 5),
#   (53, 2),
#   (54, 2),
#   (55, 1),
#   (56, 1),
#   (57, 1),
#   (58, 3),
#   (59, 1),
#   (60, 2),
#   (61, 3),
#   (62, 1),
#   (63, 1),
#   (64, 1),
#   (65, 1),
#   (66, 1),
#   (67, 1),
#   (68, 1),
#   (69, 3),
#   (70, 1),
#   (71, 1),
#   (72, 1),
#   (73, 3),
#   (74, 3),
#   (75, 3),
#   (76, 1),
# ...

# %%
Lda_model=gensim.models.LdaMulticore(bow_corpus,num_topics=9,
                                    id2word=dictionary,passes=9)

# %%
for ids,topic in Lda_model.print_topics():
    print("Topic: {}\nWord: {}".format(ids,topic),"\n")
# Out:
# Topic: 0
# Word: 0.024*"csk" + 0.020*"say" + 0.020*"dhoni" + 0.016*"time" + 0.016*"fleme" + 0.015*"du" + 0.015*"plessi" + 0.013*"bat" + 0.013*"ipl" + 0.011*"faf"
#
# Topic: 1
# Word: 0.001*"year" + 0.001*"worst" + 0.001*"india" + 0.001*"million" + 0.001*"say" + 0.001*"peopl" + 0.001*"indian" + 0.001*"time" + 0.001*"world" + 0.001*"advertis"
#
# Topic: 2
# Word: 0.001*"year" + 0.001*"worst" + 0.001*"million" + 0.001*"peopl" + 0.001*"india" + 0.001*"say" + 0.001*"histori" + 0.001*"kill" + 0.001*"historian" + 0.001*"world"
#
# Topic: 3
# Word: 0.001*"say" + 0.001*"india" + 0.001*"csk" + 0.001*"cyber" + 0.001*"year" + 0.001*"time" + 0.001*"dhoni" + 0.001*"fleme" + 0.001*"th" + 0.001*"plessi"
#
# Topic: 4
# Word: 0.015*"water" + 0.014*"say" + 0.011*"qualiti" + 0.011*"ganga" + 0.009*"weapon" + 0.009*"pollut" + 0.009*"river" + 0.009*"lockdown" + 0.008*"india" + 0.008*"arm"
#
# Topic: 5
# ...

# %%
#Testing
text_for_test="""The Jammu and Kashmir (J&K) Police confirmed that the DNA samples of the three persons, killed in the alleged fake encounter in Shopian district on July 18, had matched with their family members. The police also said an investigation is underway in the Shopian encounter case.

"The DNA samples of the three men have matched with their family members in Rajouri. We are carrying out further investigation in the matter," Vijay Kumar, IG J&K Police, said.

On July 18, the Army had claimed that three terrorists were killed in Amshipura village in the higher reaches of south Kashmir's Shopian district.

The controversy erupted after three families filed a complaint at a police station in Rajouri, stating that a member each was missing since July 17 from the Amshipora area of Shopian.

The relatives of the youths, belonging to Dhar Sakri village in Kotranka of Rajouri area in Poonch, lodged the missing report with the local police after they failed to contact the trio and news of an encounter came on July 18 from Ashimpora in Shopian, a police official said.

The families also identified the three men, killed in Shopian, as their kin and filed a police complaint. They claimed that the three were working as labourers in apple and walnut orchards.

Police had taken the DNA samples of three families from Rajouri district for matching it with the DNA of the three youths killed in the alleged fake encounter case.

As a controversy in the Shopian incident erupted, the Army released a statement, last week, stating it has found "prima facie" evidence that its troops "exceeded" powers under the Armed Forces Special Powers Act (AFSPA). The Army also said that it has initiated disciplinary proceedings.
advertisement

The family members of the three youths had also written a letter to the LG of J&K seeking his personal intervention in the alleged Shopian fake enocunter case."""

# %%
#Vectorization of test text
vec_for_test=dictionary.doc2bow(preprocess(text_for_test))

# %%
#Finding 15 topics
for index,score in (Lda_model[vec_for_test]):
    print("Score: {} \tTopic: {}".format(score,Lda_model.print_topic(index,15)))
# Out:
# Score: 0.11414620280265808 	Topic: 0.024*"csk" + 0.020*"say" + 0.020*"dhoni" + 0.016*"time" + 0.016*"fleme" + 0.015*"du" + 0.015*"plessi" + 0.013*"bat" + 0.013*"ipl" + 0.011*"faf" + 0.011*"go" + 0.010*"long" + 0.010*"th" + 0.010*"super" + 0.010*"tri"
# Score: 0.32878074049949646 	Topic: 0.015*"water" + 0.014*"say" + 0.011*"qualiti" + 0.011*"ganga" + 0.009*"weapon" + 0.009*"pollut" + 0.009*"river" + 0.009*"lockdown" + 0.008*"india" + 0.008*"arm" + 0.008*"drone" + 0.008*"jammu" + 0.008*"natur" + 0.008*"chang" + 0.006*"year"
# Score: 0.20735962688922882 	Topic: 0.039*"year" + 0.021*"million" + 0.020*"worst" + 0.015*"peopl" + 0.009*"histori" + 0.008*"say" + 0.008*"war" + 0.008*"historian" + 0.008*"kill" + 0.007*"day" + 0.007*"indian" + 0.007*"world" + 0.007*"pandem" + 0.007*"famin" + 0.007*"plagu"
# ...
